# %% [markdown]
# # Module 1

# %% [markdown]
# ## 1.1 Загрузка данных

# %% [markdown]
# ### Импорт библиотек для загрузки данных

# %%
# Импорт модуля pandas
import pandas as pd
import numpy as np
# Игнорирование предупреждений
import warnings
warnings.filterwarnings('ignore')

# %%
# Загрузка данных цели 1
target1 = pd.read_csv (r'target1.csv')
print (target1)
# Загрузка данных цели 2
target2 = pd.read_csv (r'target2.csv')
print (target2)
# Загрузка данных цели 3
target3 = pd.read_csv (r'target3.csv')
print (target3)
# Out:
#    Начало дефекта  Длина дефекта  Высота дефекта Тип дефекта Сторона
# 0              51           42.0               7           L       A
# 1             200           40.0               6           L       B
# 2             278           39.0               4           L       A
# 3             365           43.0               6           L       B
# 4             460           27.0               5           L       A
# 5             845           36.0               4           L       B
# 6             959           62.0               6           L       A
# 7             141            NaN               4           T
#    Начало дефекта  Длина дефекта  Высота дефекта Тип дефекта Сторона
# 0             178           37.0               6           L       B
# 1             258           38.0               4           L       A
# 2             337           53.0               5           L       B
# 3             822           37.0               5           L       B
# ...

# %%
# Объединение в одну таблицу
df = pd.concat([target1, target2, target3])

# %%
# Очищаем техническую информацию
df = df.dropna(axis=0)

# %%
# Импорт библиотеки
import csv
# Цикл пересборки таблицы 1
with open('SOP1.txt', 'r') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split(",") for line in stripped if line)
    with open('SOP1.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('title', 'intro'))
        writer.writerows(lines)
        
# Цикл пересборки таблицы 2
with open('SOP2.txt', 'r') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split(",") for line in stripped if line)
    with open('SOP2.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('title', 'intro'))
        writer.writerows(lines)
        
# Цикл пересборки таблицы 3
with open('SOP3.txt', 'r') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split(",") for line in stripped if line)
    with open('SOP3.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('title', 'intro'))
        writer.writerows(lines)

# %%
# Загрузка данных цели 1
SOP1 = pd.read_csv (r'SOP1.csv')
SOP1 = SOP1.drop(labels = [0],axis = 0)
# Загрузка данных цели 2
SOP2 = pd.read_csv (r'SOP2.csv')
SOP2 = SOP2.drop(labels = [0],axis = 0)
# Загрузка данных цели 3
SOP3 = pd.read_csv (r'SOP3.csv')
SOP3 = SOP3.drop(labels = [0],axis = 0)

# %% [markdown]
# ## 1.2 Предварительное изучение

# %%
# Анализ переменных в табличном виде
df.describe()
# Out:
#        Начало дефекта  Длина дефекта  Высота дефекта
# count       18.000000      18.000000       18.000000
# mean       490.388889      43.277778        5.500000
# std        345.009316       8.539221        1.248529
# min         26.000000      27.000000        4.000000
# 25%        214.500000      37.250000        5.000000
# 50%        351.000000      42.000000        5.000000
# 75%        839.250000      48.750000        6.000000
# max        971.000000      62.000000        8.000000

# %%
# Анализ переменных в табличном виде
SOP1.describe()
# Out:
#              title            5            6            7            8  \
# count  1042.000000  1042.000000  1042.000000  1042.000000  1042.000000
# mean    521.500000    16.244722    95.277351   117.201536     0.488484
# std     300.943793    49.011640    64.650667    86.584700     3.553943
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%     261.250000     0.000000    43.000000    35.000000     0.000000
# 50%     521.500000     0.000000    91.000000   113.000000     0.000000
# 75%     781.750000     0.000000   139.000000   195.000000     0.000000
# max    1042.000000   255.000000   255.000000   255.000000    63.000000
#
#                 10           11           12           13           14  \
# count  1042.000000  1042.000000  1042.000000  1042.000000  1042.000000
# mean     90.076775    63.525912     5.941459    28.148752    65.117083
# std      74.079519    73.302708    18.592899    48.783569    61.193271
# ...

# %%
# Анализ переменных в табличном виде
SOP2.describe()
# Out:
#              title            5            6            7            8  \
# count  1039.000000  1039.000000  1039.000000  1039.000000  1039.000000
# mean    520.000000    14.403272    68.232916    72.699711     0.738210
# std     300.077768    47.885602    64.115154    68.435998     7.310799
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%     260.500000     0.000000    13.000000     5.000000     0.000000
# 50%     520.000000     0.000000    53.000000    59.000000     0.000000
# 75%     779.500000     0.000000   104.500000   118.000000     0.000000
# max    1039.000000   255.000000   255.000000   255.000000   152.000000
#
#                 10           11           12           13           14  \
# count  1039.000000  1039.000000  1039.000000  1039.000000  1039.000000
# mean     41.561116    54.715111     4.525505    26.093359    61.685274
# std      54.114379    70.420808    17.918007    46.546100    58.428258
# ...

# %%
# Анализ переменных в табличном виде
SOP3.describe()
# Out:
#              title            5            6            7            8  \
# count  1038.000000  1038.000000  1038.000000  1038.000000  1038.000000
# mean    519.500000    16.554913   150.868015    80.681118     1.052987
# std     299.789093    40.423486    85.022845    61.259486     5.751197
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%     260.250000     0.000000    80.000000    29.000000     0.000000
# 50%     519.500000     0.000000   157.000000    75.000000     0.000000
# 75%     778.750000     8.000000   238.000000   118.000000     0.000000
# max    1038.000000   239.000000   255.000000   255.000000    64.000000
#
#                 10           11           12           13          14  \
# count  1038.000000  1038.000000  1038.000000  1038.000000  1038.00000
# mean     49.246628    91.547206     6.563584    55.935453    72.38632
# std      69.988640    80.183175    19.521847    75.588483    58.83306
# ...

# %% [markdown]
# Из анализа переменных видно, что **средее значение высоты дефекта** - 5.5, **минимальная высота дефекта** - 4, **максимальная высота дефекта** - 8;<br>
# **Среднее значение начала дефекта** - 490.4, **минимальное начала дефекта** - 26, **максимальная начала дефекта** - 971;<br>
# **Среднее значение длины дефекта** - 43.3, **минимальная длина дефекта** - 27, **максимальная длина дефекта** - 62.

# %% [markdown]
# ## 1.3 Определение метода контроля

# %% [markdown]
# Проанализировав два предоставленных метода УЗ контроля я выбрал *эхо-импульсивный метод (эхо-такт)*. При *эхо-импульсном* методе преобразователь используют как генератор и приемник импульсов. **Это обеспечивает простоту эксплуатации и точную установку места повреждения сварочного шва**.<br>Сущность *теневой методики* заключает в наблюдении над амплитудой УЗ-колебаний. В работе задействуют излучатель и приемник, расположенные напротив друг друга у одной стенки трубы. С увеличением размера дефекта уменьшается амплитуда, либо сигнал пропадает полностью. **В отличие от *метода эха*, *теневой* чувствителен к ориентации дефекта и обнаруживает его при любом наклоне, но более неточен в целом**. Делаем вывод: так как у нас большинство дефектов являются поперечными во всех случаях, то эхо-импульсивный метод подойдёт лучше.

# %% [markdown]
# ## 1.4 Определение расстояния между схемами прозвучания

# %%
# Отображение матрицы корреляций
corr_matrix = df.corr()
corr_matrix
# Out:
#                 Начало дефекта  Длина дефекта  Высота дефекта
# Начало дефекта        1.000000       0.209130       -0.202449
# Длина дефекта         0.209130       1.000000        0.157246
# Высота дефекта       -0.202449       0.157246        1.000000

# %%
# Отображение матрицы корреляций SOP 1
corr_matrix_SOP1 = SOP1.corr()
corr_matrix_SOP1
# Out:
#           title         5         6         7         8        10        11  \
# title  1.000000 -0.022251  0.346069  0.240691 -0.063598 -0.174923  0.026873
# 5     -0.022251  1.000000 -0.350656 -0.345212  0.003422  0.087842  0.792997
# 6      0.346069 -0.350656  1.000000  0.315589 -0.028903 -0.202805 -0.327498
# 7      0.240691 -0.345212  0.315589  1.000000 -0.022781 -0.429126 -0.413959
# 8     -0.063598  0.003422 -0.028903 -0.022781  1.000000 -0.018131  0.003102
# 10    -0.174923  0.087842 -0.202805 -0.429126 -0.018131  1.000000  0.202334
# 11     0.026873  0.792997 -0.327498 -0.413959  0.003102  0.202334  1.000000
# 12    -0.352879  0.035361 -0.262988 -0.167785  0.011554  0.100264  0.016558
# 13     0.278363 -0.079600  0.166719  0.049593 -0.052957  0.167076 -0.044539
# 14     0.098357 -0.041605  0.068534  0.065914  0.041094 -0.062695  0.126875
# 15    -0.106583 -0.037002 -0.015320  0.139541  0.030484 -0.058127  0.085744
# ...

# %%
# Отображение матрицы корреляций SOP 2
corr_matrix_SOP2 = SOP2.corr()
corr_matrix_SOP2
# Out:
#           title         5         6         7         8        10        11  \
# title  1.000000 -0.095214  0.167379 -0.142249 -0.016136 -0.329773 -0.076193
# 5     -0.095214  1.000000 -0.226732 -0.262995  0.032018  0.051724  0.780481
# 6      0.167379 -0.226732  1.000000 -0.034494 -0.044415 -0.005455 -0.232142
# 7     -0.142249 -0.262995 -0.034494  1.000000 -0.052933 -0.172129 -0.282247
# 8     -0.016136  0.032018 -0.044415 -0.052933  1.000000 -0.047961 -0.027095
# 10    -0.329773  0.051724 -0.005455 -0.172129 -0.047961  1.000000  0.059082
# 11    -0.076193  0.780481 -0.232142 -0.282247 -0.027095  0.059082  1.000000
# 12    -0.308814  0.006080 -0.195806  0.004202 -0.024836  0.200614 -0.039322
# 13     0.246012 -0.088057 -0.127013 -0.063678  0.047346 -0.002325 -0.060305
# 14     0.109601 -0.092302  0.169630  0.013962 -0.053683 -0.083715  0.024142
# 15    -0.285377 -0.047627 -0.083157  0.321933 -0.041228 -0.049890  0.000566
# ...

# %%
# Отображение матрицы корреляций SOP 3
corr_matrix_SOP3 = SOP3.corr()
corr_matrix_SOP3
# Out:
#           title         5         6         7         8        10        11  \
# title  1.000000 -0.045928  0.145435 -0.095978 -0.072440  0.063109 -0.128446
# 5     -0.045928  1.000000 -0.232368 -0.145209 -0.023434 -0.010469  0.746481
# 6      0.145435 -0.232368  1.000000  0.354972 -0.120076 -0.478270 -0.361045
# 7     -0.095978 -0.145209  0.354972  1.000000 -0.012627 -0.385719 -0.213043
# 8     -0.072440 -0.023434 -0.120076 -0.012627  1.000000 -0.051272  0.062807
# 10     0.063109 -0.010469 -0.478270 -0.385719 -0.051272  1.000000  0.081709
# 11    -0.128446  0.746481 -0.361045 -0.213043  0.062807  0.081709  1.000000
# 12    -0.097284  0.089203  0.005377  0.002906 -0.050512 -0.125666  0.000124
# 13    -0.118675 -0.092326 -0.009092 -0.201054 -0.065264  0.258531  0.090720
# 14     0.249986 -0.122231  0.250692  0.156538 -0.005641 -0.138452 -0.083012
# 15     0.238795 -0.297588  0.312196  0.131275  0.002655 -0.134657 -0.366813
# ...

# %%
# Импорт библиотеки
import seaborn as sns
# Отображение тепловой карты
sns.heatmap(df.corr());

# %%
# Импорт библиотеки
import seaborn as sns
# Отображение тепловой карты SOP 1
sns.heatmap(SOP1.corr());

# %%
# Импорт библиотеки
import seaborn as sns
# Отображение тепловой карты SOP 2
sns.heatmap(SOP2.corr());

# %%
# Импорт библиотеки
import seaborn as sns
# Отображение тепловой карты SOP 3
sns.heatmap(SOP3.corr());

# %% [markdown]
# Оценив текстовый и графический вид представления корреляционной модели можно сделать вывод, что коррелирующих признаков нет.

# %% [markdown]
# ## 1.5 Определение схем прозвучивания

# %% [markdown]
# Для контроля сварочных швов применяют "прозвучивание" *прямым лучом*, *прямым и однократно отражённым*, *многократно отражённым лучом*. Эти методы основаны на *эхо* и *теневом* методах.<br>
# **Толщина шва находится в диапазоне (по минимальному и максимальному значениям) от 4 мм до 8 мм**. Руководствуясь справочным материалом В.В. Овчинникова "Дефектация сварочных швов и контроль качества сварочных соединений", в котором пишут, что *единственный способ пригодный для "прозвучивания" швов толщиной от 3.5 мм до 10.0 мм, выполненных одностронней сварккой с проплавлением* (что видно из необходимых приложений, выданных для выполнения задания), *в которых дефекты находятся в основном в корне шва*. **Единственным недостатком такого метода является наличие "мёртвой зоны"**.
# <br>Выбор стороны зависит от дефектов швов, являются ли они продольными или поперечными. В нашем случае большинство поперечных швов, поэтому сторона не имеет для нас значение.
# <br> Хордовые применяют для контроля кольцевых сварных швов трубных элементов из сталей и полиэтилена диаметром от 14 до 219 мм. с толщиной стенки от 2 до 6 мм., используются контактные раздельно-совмещенные хордовые преобразователи. Применение преобразователей хордового типа особенно эффективно для контроля тонкостенных сварных швов от 2 до 4 мм.
#
# <br>**Вывод: Хордовая, Эхо-поперечные, Сторона А или Б**

# %% [markdown]
# ## 1.6 Приведение к общей координате

# %%
# Объединение в одну таблицу
SOP = pd.concat([SOP1, SOP2, SOP3])
# Удаляем заголовок
SOP = SOP.drop(['title'], axis=1)

# %% [markdown]
# ## 1.7 Отчёт

# %%
#Сохранение в CSV
SOP.to_csv('SOP.csv')
df.to_csv('target.csv')

# %%
#Сохранение HTML
# !jupyter nbconvert С2_M1.ipynb --to html
# Out:
# ЋвЄ § ­® ў ¤®бвгЇҐ.
